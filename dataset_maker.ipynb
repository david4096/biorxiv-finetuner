# %%
from datasets import Dataset, IterableDataset

# %%
import json

# %%
with open("output.jsonl", 'r') as f:
    gen = (json.loads(line) for line in f)

# %%
ds = IterableDataset.from_generator(gen)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds = IterableDataset.from_generator(gen)
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/iterable_dataset.py:1914, in IterableDataset.from_generator(generator, features, gen_kwargs)
#    1873 """Create an Iterable Dataset from a generator.
#    1874
#    1875 Args:
#    (...)
#    1910 ```
#    1911 """
#    1912 from .io.generator import GeneratorDatasetInputStream
# -> 1914 return GeneratorDatasetInputStream(
#    1915     generator=generator,
#    1916     features=features,
#    1917     gen_kwargs=gen_kwargs,
#    1918     streaming=True,
#    1919 ).read()
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/io/generator.py:28, in GeneratorDatasetInputStream.__init__(self, generator, features, cache_dir, keep_in_memory, streaming, gen_kwargs, num_proc, **kwargs)
#       9 def __init__(
#      10     self,
#      11     generator: Callable,
#    (...)
#      18     **kwargs,
#      19 ):
#      20     super().__init__(
#      21         features=features,
#      22         cache_dir=cache_dir,
#    (...)
#      26         **kwargs,
#      27     )
# ---> 28     self.builder = Generator(
#      29         cache_dir=cache_dir,
#      30         features=features,
#      31         generator=generator,
#      32         gen_kwargs=gen_kwargs,
#      33         **kwargs,
#      34     )
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/builder.py:374, in DatasetBuilder.__init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, use_auth_token, repo_id, data_files, data_dir, storage_options, writer_batch_size, name, **config_kwargs)
#     372     config_kwargs["data_dir"] = data_dir
#     373 self.config_kwargs = config_kwargs
# --> 374 self.config, self.config_id = self._create_builder_config(
#     375     config_name=config_name,
#     376     custom_features=features,
#     377     **config_kwargs,
#     378 )
#     380 # prepare info: DatasetInfo are a standardized dataclass across all datasets
#     381 # Prefill datasetinfo
#     382 if info is None:
#     383     # TODO FOR PACKAGED MODULES IT IMPORTS DATA FROM src/packaged_modules which doesn't make sense
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/builder.py:635, in DatasetBuilder._create_builder_config(self, config_name, custom_features, **config_kwargs)
#     629 builder_config._resolve_data_files(
#     630     base_path=self.base_path,
#     631     download_config=DownloadConfig(token=self.token, storage_options=self.storage_options),
#     632 )
#     634 # compute the config id that is going to be used for caching
# --> 635 config_id = builder_config.create_config_id(
#     636     config_kwargs,
#     637     custom_features=custom_features,
#     638 )
#     639 is_custom = (config_id not in self.builder_configs) and config_id != "default"
#     640 if is_custom:
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/builder.py:193, in BuilderConfig.create_config_id(self, config_kwargs, custom_features)
#     191             suffix = Hasher.hash(config_kwargs_to_add_to_suffix)
#     192     else:
# --> 193         suffix = Hasher.hash(config_kwargs_to_add_to_suffix)
#     195 if custom_features is not None:
#     196     m = Hasher()
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/fingerprint.py:228, in Hasher.hash(cls, value)
#     226 @classmethod
#     227 def hash(cls, value: Any) -> str:
# --> 228     return cls.hash_bytes(dumps(value))
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/utils/_dill.py:109, in dumps(obj)
#     107 """Pickle an object to a string."""
#     108 file = BytesIO()
# --> 109 dump(obj, file)
#     110 return file.getvalue()
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/utils/_dill.py:103, in dump(obj, file)
#     101 def dump(obj, file):
#     102     """Pickle an object to a file."""
# --> 103     Pickler(file, recurse=True).dump(obj)
#
# File ~/git/imfine/env/lib/python3.12/site-packages/dill/_dill.py:420, in Pickler.dump(self, obj)
#     418 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     419     logger.trace_setup(self)
# --> 420     StockPickler.dump(self, obj)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:481, in _Pickler.dump(self, obj)
#     479 if self.proto >= 4:
#     480     self.framer.start_framing()
# --> 481 self.save(obj)
#     482 self.write(STOP)
#     483 self.framer.end_framing()
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~/git/imfine/env/lib/python3.12/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:554, in _Pickler.save(self, obj, save_persistent_id)
#     552 f = self.dispatch.get(t)
#     553 if f is not None:
# --> 554     f(self, obj)  # Call unbound method with explicit self
#     555     return
#     557 # Check private dispatch table if any, or else
#     558 # copyreg.dispatch_table
#
# File ~/git/imfine/env/lib/python3.12/site-packages/dill/_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:966, in _Pickler.save_dict(self, obj)
#     963     self.write(MARK + DICT)
#     965 self.memoize(obj)
# --> 966 self._batch_setitems(obj.items())
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:990, in _Pickler._batch_setitems(self, items)
#     988     for k, v in tmp:
#     989         save(k)
# --> 990         save(v)
#     991     write(SETITEMS)
#     992 elif n:
#
# File ~/git/imfine/env/lib/python3.12/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File ~/git/imfine/env/lib/python3.12/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:572, in _Pickler.save(self, obj, save_persistent_id)
#     570 reduce = getattr(obj, "__reduce_ex__", None)
#     571 if reduce is not None:
# --> 572     rv = reduce(self.proto)
#     573 else:
#     574     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'generator' object
